# %% [markdown]
# # AgriX AI: Cloud GPU Training Pipeline (Google Colab / Kaggle)
#
# Run this notebook on Google Colab (with free T4 GPU) to train the MobileNetV3 model on the curated plant disease dataset.

# %%
# Step 1: Clone repo or sync ML directory and install dependencies
# !pip install -r ../requirements.txt

# %%
# Step 2: Run training script
# !python ../src/training/train.py --config ../configs/training_config.yaml

# %%
# Step 3: Run independent test evaluation
# !python ../src/evaluation/evaluate.py --config ../configs/training_config.yaml --checkpoint ../models/best_model.pth

# %%
# Step 4: Export to INT8 Quantized TFLite for Android deployment
# !python ../src/export/export_tflite.py --config ../configs/training_config.yaml --checkpoint ../models/best_model.pth --output ../models/disease_model.tflite --quantize int8
